# %% [markdown]
# __1.__ Исследовать на линейную зависимость:
# $$f_{1}(x)=e^{x}, f_{2}(x)=1, f_{3}(x)=x+1, f_{4}(x)=x-e^{x}.$$
#
# $$f_{4}(x)=x-e^{x}=x+1-1-e^{x}=f_{3}(x)-f_{2}(x)-f_{1}(x)$$
# Коли один из векторов можно линейно выразить через другие, то и следует заключить, что вектора зависимы.

# %% [markdown]
# __2.__ Исследовать на линейную зависимость:
# $$f_{1}(x)=2, f_{2}(x)=x, f_{3}(x)=x^{2}, f_{4}(x)=(x+1)^{2}.$$
#
# $$f_{4}(x)=(x+1)^{2} = x^{2} + 2x + 1 = f_{3}(x) + 2f_{2}(x) + {f_{1}(x)}{\over2}$$
#
# Коли один из векторов можно линейно выразить через другие, то и следует заключить, что вектора зависимы.

# %% [markdown]
# __3.__ Найти координаты вектора $x = (2, 3, 5)\in \mathbb{R}^{3}$ в базисе $b_{1}=(0, 0, 10)$, $b_{2}=(2, 0, 0)$, $b_{3}=(0, 1, 0)$.
#
# $$𝑥=(2,3,5) = (2,0,0) + (0,3,0) + (0,0,5) = b_2 + 3b_3 + 0.5b_1$$
#
# то есть координаты вектора $x$ в базисе равны $0.5, 1, 3$

# %% [markdown]
# __4.__ Найти координаты вектора $3x^{2}-2x+2\in\mathbb{R}^{3}[x]$:
#
#    а) в базисе $1$, $x$, $x^{2}$;
#
#    Координаты вектора в базисе равны $3, -2, 2$
#
#    б) в базисе $x^{2}$, $x-1$, $1$.
#
#    Координаты вектора в базисе равны $3, -2, 0$

# %% [markdown]
# __5.__ Установить, является ли линейным подпространством:
#
#
# а) совокупность всех векторов трехмерного пространства, у которых по крайней мере одна из первых двух координат равна нулю;
# значит могут быть комбинации элементов подпространства могут быть:
# Трехмерное, значит $\mathbb{R}^{3}$
#
# a) (0,a,b)+(0,c,d) = (0, a+c, b+d)
#
# б) (a,0,b)+(c,0,d) = (a+c, 0, b+d)
#
# в) (a,0,b)+(0,c,d) = (a, c, b+d)
#
# г) (0,a,b)+(c,0,d) = (c, a, b+d)
#
# д) (0,0,b)+(0,c,d) = (0, c, b+d)
#
# е) (0,0,b)+(c,0,d) = (c, 0, b+d)
#
# ж) (a,0,b)+(0,0,d) = (a, 0, b+d)
#
# з) (0,a,b)+(0,0,d) = (0, a, b+d)
#
# и) (0,0,b)+(0,0,d) = (0, 0, b+d)
#
# Пункты в и г не удовлетворяют условиям подпространства, соответственно совокупность не является подпространством.
#
# б) все векторы, являющиеся линейными комбинациями данных векторов $\{u_{1}, u_{2}, ..., u_{n}\}$.
# Согласно определению:
#
# Возьмем в $n$-мерном линейном пространстве конечный набор векторов ${x1,x2,...,xk}$. Тогда совокупность всех линейных комбинаций этих векторов образует некоторое подпространство исходного линейного пространства. Она будет называться линейной оболочкой этого множества и обозначаться  $L{x1,x2,...,xk}$.
#
# Следовательно все комбинации исходных векторов будут подпространством.
