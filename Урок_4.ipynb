# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# 3. Задание (в программе или на листочке)
# На листе тетради «в линейку» (расстояние между линиями равно а) лежит игла (длиной b). Координаты нижней точки иглы (х,у), игла лежит под углом alfa. Пересекает ли игла линию или нет?

# %%
print('Возьмем за начало координат нижний левый угол листа. Тогда все x и y нижней точки иглы больше 0.')
a = int(input('Введите расстояние между линиями: '))
x0 = int(input('Введите координату x нижней точки иглы(x>0): '))
y0 = int(input('Введите координату y нижней точки иглы(y>0): '))
b = int(input('Введите длину иглы: '))
alpha = int(input('Введите угол, под которым лежит игла: '))/180*np.pi

x1 = x0+np.cos(alpha)*b
y1 = y0+np.sin(alpha)*b
line_0 = y0//a
print(line_0)
line_1 = line_0 + a
print()
if (y1 >= line_1) or (y1 <= line_0) or (y0 == line_0):
    print('Игла пересекает линию')
else:
    print('Игла не пересекает линию')

plt.plot([x0,x1], [line_0, line_0])
plt.plot([x0,x1], [line_1, line_1])
plt.plot([x0,x1], [y0, y1])
# Out:
# Возьмем за начало координат нижний левый угол листа. Тогда все x и y нижней точки иглы больше 0.
# Введите расстояние между линиями: 2
# Введите координату x нижней точки иглы(x>0): 1
# Введите координату y нижней точки иглы(y>0): -1
# Введите длину иглы: 2
# Введите угол, под которым лежит игла: 30
# -1
#
# Игла пересекает линию

# %%
a = np.linspace(0.01, 0.02, 100)
x_min = 100
x_max = 500
n_max = np.max(a)*np.max(x_max)//np.pi
N = np.linspace(1., n_max, n_max)
print(N)
for n in N:
    x=(n*np.pi)/a
    plt.plot(a,x)
# Out:
# [1. 2. 3.]
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: object of type <class 'numpy.float64'> cannot be safely interpreted as an integer.
#   """

# %%
x = np.array([0,10])
y1=[(3*i-12)/4 for i in x]
y2=[(14-i)/7 for i in x]

a1 = np.arccos(abs(10/np.sqrt(10**2+(y1[1]-y1[0])**2)))*180/(np.pi)
a2 = np.arccos(abs(10/np.sqrt(10**2+(y2[1]-y2[0])**2)))*180/(np.pi)

print(f'Прямые под углом {round(a1+a2,0)} градусов друг к другу')


plt.figure(figsize=(8,8))
plt.xlim(0,10)
plt.ylim(-5,5)
plt.grid(True)

plt.plot(x,y1)
plt.plot(x,y2)
# Out:
# Прямые под углом 45.0 градусов друг к другу

# %%
x = np.linspace(4.5, 10, 1000)
y = np.sqrt(2*x-9)+2
plt.plot(x,y)
y = -np.sqrt(2*x-9)+2
plt.plot(x,y)

# %%
x = np.linspace(-12, 3.874, 1000)
y = np.sqrt((186-3*((x+4)**2))/5)+6
plt.plot(x,y)
y = -np.sqrt((186-3*((x+4)**2))/5)+6
plt.plot(x,y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in sqrt
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in sqrt
#   after removing the cwd from sys.path.

# %%
x = np.linspace(-12, 12, 1000)
y = np.sqrt(2*x**2+29)+6
plt.plot(x,y)
y = -np.sqrt(2*x**2+29)+6
plt.plot(x,y)

# %%
x = np.linspace(-50, 50, 500)

y = (np.sqrt(2*(x-14)**2+337)/3)-14
plt.plot(x,y)
y = -(np.sqrt(2*(x-14)**2+337)/3)-14
plt.plot(x,y)
