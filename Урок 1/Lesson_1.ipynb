# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
k1 = 1
k2 = 0.75

# %%
x = np.linspace(0, 20, 121)

# %%
y1 = np.cos(k1*x)

# %%
y2 = np.cos(k2*x)

# %%
plt.plot(y1)
plt.plot(y2)
